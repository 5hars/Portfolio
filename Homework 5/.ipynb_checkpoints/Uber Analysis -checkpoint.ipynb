# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import seaborn as sns
import csv 
import os

color_scheme = {'Gold':'#FFD700', 'Light Sky Blue':'#87CEFA', 'Light Coral':'#F08080'}

# %%
# Import cities file as DataFrame and merge
city_pd = pd.read_csv("city_data.csv")
ride_pd = pd.read_csv("ride_data.csv")
merged_data = pd.merge(ride_pd, city_pd, on="city")
merged_data.head(10)
# Out:
#        city                 date   fare        ride_id  driver_count   type
# 0  Sarabury  2016-01-16 13:49:27  38.35  5403689035038            46  Urban
# 1  Sarabury  2016-07-23 07:42:44  21.76  7546681945283            46  Urban
# 2  Sarabury  2016-04-02 04:32:25  38.03  4932495851866            46  Urban
# 3  Sarabury  2016-06-23 05:03:41  26.82  6711035373406            46  Urban
# 4  Sarabury  2016-09-30 12:48:34  30.30  6388737278232            46  Urban
# 5  Sarabury  2016-08-04 00:25:52  27.20  2429366407526            46  Urban
# 6  Sarabury  2016-07-25 10:44:01  17.73  4467299640441            46  Urban
# 7  Sarabury  2016-06-22 16:24:01  23.94  6153395712431            46  Urban
# 8  Sarabury  2016-01-27 17:46:45  16.39  8220809448298            46  Urban
# 9  Sarabury  2016-04-26 11:31:30  21.80  5969441875705            46  Urban

# %%
#group city together
city_group = merged_data.groupby('city')

#Avg fare per city
avg_fare = city_group.mean()['fare']

#Rides per city
ride_count = city_group['ride_id'].count()

#Driver Count
driver_count = city_group.mean()['driver_count']

#City Type
city_type = city_group["type"].unique()


city_data = pd.DataFrame({
    "Number of Rides": ride_count,
    "Average Fare": avg_fare,
    "Number of Drivers": driver_count,
    "Type of City": city_type
})


city_data.sort_values('Number of Drivers', ascending = False)

#separated dfs for city categories
rural = city_data[city_data['Type of City'] == 'Rural']
suburban = city_data[city_data['Type of City'] == 'Suburban']
urban = city_data[city_data['Type of City'] == 'Urban']

#Color Dictionary 
city_color = {'Urban': color_scheme['Light Coral'], 'Suburban': color_scheme['Light Sky Blue'], 'Rural': color_scheme['Gold']}

# scatter plot points
plt.scatter(rural['Number of Rides'], rural['Average Fare'], s = rural['Number of Drivers']*10, color = city_color['Rural'], edgecolor = 'black', label = 'Rural', alpha = .75)
plt.scatter(suburban['Number of Rides'], suburban['Average Fare'], s = suburban['Number of Drivers']*10, color = city_color['Suburban'], edgecolor = 'black', label = 'Suburban', alpha = .75)
plt.scatter(urban['Number of Rides'], urban['Average Fare'], s = urban['Number of Drivers']*10, color = city_color['Urban'], edgecolor = 'black', label = 'Urban', alpha = .75)


plt.title('Pyber Ride Sharing Data (2016)')
plt.xlabel('Number of Rides per City')
plt.ylabel('Average Fare per City')


plt.show()

# %%
# % of Total Fares by City Type
combined_df = merged_data.groupby('type')['type', 'fare', 'ride_id', 'driver_count']
type_label = ["Rural", "Suburban", "Urban"]
colors = ["red","lightskyblue","gold"]
explode = (0,0,0.1)
combined_df.head()
# Out:
#           type   fare        ride_id  driver_count
# 0        Urban  38.35  5403689035038            46
# 1        Urban  21.76  7546681945283            46
# 2        Urban  38.03  4932495851866            46
# 3        Urban  26.82  6711035373406            46
# 4        Urban  30.30  6388737278232            46
# 1625  Suburban  15.77  2259499336994            15
# 1626  Suburban  15.77  2259499336994             3
# 1627  Suburban  26.26  4051110168629            15
# 1628  Suburban  26.26  4051110168629             3
# 1629  Suburban  20.25  3994763896598            15
# 2282     Rural  12.63  8214498891817             8
# 2283     Rural  31.53  1797785685674             8
# 2284     Rural  21.73  5665544449606             8
# 2285     Rural  20.04  5729327140644             8
# 2286     Rural  20.53  6432117120069             3

# %%
total_fares = combined_df["fare"].sum()

plt.pie(total_fares, explode = explode, label= type_label, colors=colors,
        autopct="%1.1f%%", shadow=True, startangle=140)

plt.title('% Total Fares by City Type')
plt.axis('equal')
plt.show()
# Out:
# ---------------------------------------------------------------------------
# Exception                                 Traceback (most recent call last)
# <ipython-input-18-b735663691a0> in <module>()
# ----> 1 total_fares = combined_df.fare.sum()
#       2
#       3 plt.pie(total_fares, explode = explode, label= type_label, colors=colors,
#       4         autopct="%1.1f%%", shadow=True, startangle=140)
#       5
#
# /anaconda/lib/python3.6/site-packages/pandas/core/groupby.py in __getattr__(self, attr)
#     544             return object.__getattribute__(self, attr)
#     545         if attr in self.obj:
# --> 546             return self[attr]
#     547         if hasattr(self.obj, attr):
#     548             return self._make_wrapper(attr)
#
# /anaconda/lib/python3.6/site-packages/pandas/core/base.py in __getitem__(self, key)
#     335     def __getitem__(self, key):
#     336         if self._selection is not None:
# --> 337             raise Exception('Column(s) %s already selected' % self._selection)
#     338
#     339         if isinstance(key, (list, tuple, ABCSeries, ABCIndexClass,
#
# Exception: Column(s) ['type', 'fare', 'ride_id', 'driver_count'] already selected

# %%
# % of Total Rides by City Type
total_count = combined_df["avg_fare"].count()

plt.pie(total_count, explode=explode, labels=type_label, colors=color_scheme,
        autopct="%1.1f%%", shadow=True, startangle=140)

plt.title('% Total Rides by City Type')

plt.axis('equal')

#plt.savefig("%rides_type")
plt.show()
# Out:
# ---------------------------------------------------------------------------
# Exception                                 Traceback (most recent call last)
# <ipython-input-12-ad44ab4aa962> in <module>()
#       1 # % of Total Rides by City Type
# ----> 2 total_count = combined_df["avg_fare"].count()
#       3
#       4 plt.pie(total_count, explode=explode, labels=fares_label, colors=color_scheme,
#       5         autopct="%1.1f%%", shadow=True, startangle=140)
#
# /anaconda/lib/python3.6/site-packages/pandas/core/base.py in __getitem__(self, key)
#     335     def __getitem__(self, key):
#     336         if self._selection is not None:
# --> 337             raise Exception('Column(s) %s already selected' % self._selection)
#     338
#     339         if isinstance(key, (list, tuple, ABCSeries, ABCIndexClass,
#
# Exception: Column(s) ['type', 'fare', 'ride_id', 'driver_count'] already selected

# %%
# % of Total Drivers by City Type
total_drivers = combined_df["driver_count"]

plt.pie(total_drivers, explode=explode, labels=type_label, colors=colors,
        autopct="%1.1f%%", shadow=True, startangle=140)

plt.title('% Total Drivers by City Type')

plt.axis('equal')

#plt.savefig("%rides_type")
plt.show()
# Out:
# ---------------------------------------------------------------------------
# Exception                                 Traceback (most recent call last)
# <ipython-input-20-b61e0834454e> in <module>()
#       1 # % of Total Drivers by City Type
# ----> 2 total_drivers = combined_df["driver_count"]
#       3
#       4 plt.pie(total_drivers, explode=explode, labels=type_label, colors=colors,
#       5         autopct="%1.1f%%", shadow=True, startangle=140)
#
# /anaconda/lib/python3.6/site-packages/pandas/core/base.py in __getitem__(self, key)
#     335     def __getitem__(self, key):
#     336         if self._selection is not None:
# --> 337             raise Exception('Column(s) %s already selected' % self._selection)
#     338
#     339         if isinstance(key, (list, tuple, ABCSeries, ABCIndexClass,
#
# Exception: Column(s) ['type', 'fare', 'ride_id', 'driver_count'] already selected
